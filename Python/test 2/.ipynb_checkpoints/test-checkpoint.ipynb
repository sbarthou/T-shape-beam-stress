# %%
import pandas as pd

df = pd.read_excel('data.xlsx')
df.head()
# Out:
#    Ancho viga (mm)  Altura viga (mm)  Ancho ala (mm)  Altura ala (mm)
# 0              100               100             100                6  \
# 1              100               100             100                6
# 2              100               100             100                6
# 3              100               100             100                6
# 4              100               100             100                6
#
#    Ancho alma (mm)  Altura alma (mm)  Área viga (m^2)  Wpp viga (ton/m)
# 0                6                88         0.001728          0.013565  \
# 1                8                88         0.001904          0.014946
# 2               10                88         0.002080          0.016328
# 3               12                88         0.002256          0.017710
# 4               14                88         0.002432          0.019091
#
#    Sigma max (ton/m^2)  Sigma adm (ton/m^2)
# 0         2.089547e+06                15180
# ...

# %%
sigma = df[df['Sigma max (ton/m^2)'] <= df['Sigma adm (ton/m^2)']]
sigma[sigma['Wpp viga (ton/m)'] == sigma['Wpp viga (ton/m)'].min()]
# Out:
# Empty DataFrame
# Columns: [Ancho viga (mm), Altura viga (mm), Ancho ala (mm), Altura ala (mm), Ancho alma (mm), Altura alma (mm), Área viga (m^2), Wpp viga (ton/m), Sigma max (ton/m^2), Sigma adm (ton/m^2)]
# Index: []

# %%
sigma.loc[sigma['Wpp viga (ton/m)'].nsmallest(10).index]
# Out:
# Empty DataFrame
# Columns: [Ancho viga (mm), Altura viga (mm), Ancho ala (mm), Altura ala (mm), Ancho alma (mm), Altura alma (mm), Área viga (m^2), Wpp viga (ton/m), Sigma max (ton/m^2), Sigma adm (ton/m^2)]
# Index: []
